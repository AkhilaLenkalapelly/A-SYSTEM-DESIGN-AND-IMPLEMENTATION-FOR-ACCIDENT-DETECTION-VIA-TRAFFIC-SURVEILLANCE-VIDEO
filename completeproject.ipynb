# %%
import cv2
import os
import numpy as np
import geocoder
from ultralytics import YOLO
from twilio.rest import Client
from keras.models import load_model
from keras.preprocessing.image import img_to_array
from sklearn.metrics import accuracy_score, precision_score, f1_score, confusion_matrix
from tkinter import Tk, filedialog, Button, Label
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# Load CNN model
cnn_model = load_model("accident_model.h5", compile=False)
CLASS_LABELS = ["accident", "no_accident"]

# Load YOLO model
yolo_model = YOLO("yolov8n.pt")
VEHICLE_CLASSES = ["car", "motorbike", "bus", "truck"]

# Twilio Credentials
account_sid = 'AC00803d869a7761245fe3144469f65360'
auth_token = 'af09fe4a418dd8a76c7c996803e878d3'
twilio_client = Client(account_sid, auth_token)

# Logging CSV
LOG_FILE = "accident_log.csv"
if not os.path.exists(LOG_FILE):
    pd.DataFrame(columns=["Time", "Vehicle Count", "Motion Intensity", "CNN Result", "Latitude", "Longitude"]).to_csv(LOG_FILE, index=False)


def detect_vehicles(frame):
    results = yolo_model(frame)
    detected_objects = results[0].boxes.data.cpu().numpy() if results[0].boxes.data is not None else []
    vehicles = [obj for obj in detected_objects if yolo_model.names[int(obj[5])] in VEHICLE_CLASSES and obj[4] > 0.5]
    return len(vehicles)


def calculate_optical_flow(prev_frame, next_frame):
    prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)
    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)
    flow = cv2.calcOpticalFlowFarneback(prev_gray, next_gray, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, _ = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    motion_score = np.sum(magnitude)
    return motion_score


def classify_frame_with_cnn(frame):
    frame_resized = cv2.resize(frame, (64, 64))
    frame_array = img_to_array(frame_resized) / 255.0
    frame_array = np.expand_dims(frame_array, axis=0)
    prediction = cnn_model.predict(frame_array, verbose=0)
    label = CLASS_LABELS[np.argmax(prediction)]
    return label


def send_alert_message(lat, lng):
    try:
        message_body = f"Met an Accident! Help me.\nLocation: https://www.google.com/maps?q={lat},{lng}"
        message = twilio_client.messages.create(
            from_='+18788677836',
            body=message_body,
            to='+919381623527'
        )
        print("Alert sent. Message SID:", message.sid)
    except Exception as e:
        print("Error sending alert:", e)


def log_event(vehicle_count, motion_score, cnn_result, lat, lng):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    new_row = pd.DataFrame([[timestamp, vehicle_count, motion_score, cnn_result, lat, lng]],
                           columns=["Time", "Vehicle Count", "Motion Intensity", "CNN Result", "Latitude", "Longitude"])
    new_row.to_csv(LOG_FILE, mode='a', header=False, index=False)


def extract_frames_to_dataset(video_path, output_dir='test_dataset', label='accident'):
    os.makedirs(os.path.join(output_dir, label), exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        frame_path = os.path.join(output_dir, label, f"frame_{frame_count}.jpg")
        cv2.imwrite(frame_path, frame)
        frame_count += 1
    cap.release()
    print(f"Extracted {frame_count} frames to {os.path.join(output_dir, label)}")


def evaluate_model(test_dir='test_dataset'):
    true_labels = []
    pred_labels = []

    for label in CLASS_LABELS:
        label_dir = os.path.join(test_dir, label)
        if not os.path.isdir(label_dir):
            continue

        for fname in os.listdir(label_dir):
            if fname.endswith(('.jpg', '.png', '.jpeg')):
                img_path = os.path.join(label_dir, fname)
                img = cv2.imread(img_path)
                if img is None:
                    continue
                img_resized = cv2.resize(img, (64, 64))
                img_array = img_to_array(img_resized) / 255.0
                img_array = np.expand_dims(img_array, axis=0)
                prediction = cnn_model.predict(img_array, verbose=0)
                pred_label = CLASS_LABELS[np.argmax(prediction)]
                true_labels.append(label)
                pred_labels.append(pred_label)

    if true_labels and pred_labels:
        acc = accuracy_score(true_labels, pred_labels)
        prec = precision_score(true_labels, pred_labels, pos_label='accident', zero_division=0)
        f1 = f1_score(true_labels, pred_labels, pos_label='accident', zero_division=0)
        cm = confusion_matrix(true_labels, pred_labels, labels=CLASS_LABELS)

        print("\nModel Evaluation Results:")
        print(f"Accuracy: {acc:.4f}")
        print(f"Precision: {prec:.4f}")
        print(f"F1-score: {f1:.4f}")

        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=CLASS_LABELS, yticklabels=CLASS_LABELS)
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title("Confusion Matrix")
        plt.show()

        return acc
    else:
        print("No valid predictions could be made. Please check your test dataset.")
        return None



def process_video(video_path):
    extract_frames_to_dataset(video_path, label='accident')
    cap = cv2.VideoCapture(video_path)
    prev_frame = None
    alert_sent = False

    location = geocoder.ip('me')
    lat, lng = location.latlng if location.ok else ("Unknown", "Unknown")

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if prev_frame is not None:
            motion_score = calculate_optical_flow(prev_frame, frame)
            num_vehicles = detect_vehicles(frame)
            cnn_result = classify_frame_with_cnn(frame)

            accident_detected = motion_score > 5000 and cnn_result == "accident"

            if not accident_detected:
                cnn_result = "no_accident"

            display_text = f"Vehicles: {num_vehicles}, Motion: {motion_score:.2f}, CNN: {cnn_result}"
            print(display_text)
            print("Accident Detected." if accident_detected else "No Accident Detected. CNN:", cnn_result)

            if accident_detected and not alert_sent:
                send_alert_message(lat, lng)
                log_event(num_vehicles, motion_score, cnn_result, lat, lng)
                alert_sent = True

            cv2.putText(frame, display_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8,
                        (0, 0, 255) if accident_detected else (0, 255, 0), 2)
            cv2.imshow("Accident Detection", frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        prev_frame = frame

    cap.release()
    cv2.destroyAllWindows()
    evaluate_model()


def open_file():
    video_path = filedialog.askopenfilename(title="Select video", filetypes=[("MP4 files", "*.mp4")])
    if video_path:
        process_video(video_path)

from tkinter import messagebox  # Ensure this is imported at the top

def evaluate_model(test_dir='test_dataset'):
    true_labels = []
    pred_labels = []

    for label in CLASS_LABELS:
        label_dir = os.path.join(test_dir, label)
        if not os.path.isdir(label_dir):
            continue

        for fname in os.listdir(label_dir):
            if fname.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(label_dir, fname)
                img = cv2.imread(img_path)
                if img is None:
                    continue
                img_resized = cv2.resize(img, (64, 64))
                img_array = img_to_array(img_resized) / 255.0
                img_array = np.expand_dims(img_array, axis=0)
                prediction = cnn_model.predict(img_array, verbose=0)
                pred_label = CLASS_LABELS[np.argmax(prediction)]
                true_labels.append(label)
                pred_labels.append(pred_label)

    if true_labels and pred_labels:
        acc = accuracy_score(true_labels, pred_labels)
        prec = precision_score(true_labels, pred_labels, pos_label='accident', zero_division=0)
        f1 = f1_score(true_labels, pred_labels, pos_label='accident', zero_division=0)

        print("\nModel Evaluation Results:")
        print(f"Accuracy : {acc:.4f}")
        print(f"Precision: {prec:.4f}")
        print(f"F1-score : {f1:.4f}")

        # Display in GUI popup
        messagebox.showinfo("Model Accuracy", f"Accuracy: {acc:.4f}\nPrecision: {prec:.4f}\nF1-score: {f1:.4f}")
    else:
        print("No valid predictions found.")
        messagebox.showwarning("Evaluation", "No valid predictions could be made.\nCheck your test dataset.")




def launch_gui():
    window = Tk()
    window.title("Accident Detection System")
    window.geometry("400x200")

    label = Label(window, text="Select a video to process", font=("Arial", 14))
    label.pack(pady=20)

    select_button = Button(window, text="Select Video", font=("Arial", 12), command=open_file)
    select_button.pack()

    window.mainloop()


if __name__ == "__main__":
    launch_gui()
# Out:
# Extracted 229 frames to test_dataset\accident
#
# 0: 384x640 (no detections), 118.7ms
# Speed: 6.7ms preprocess, 118.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 3678.63, CNN: no_accident
# No Accident Detected. CNN: no_accident
#
# 0: 384x640 (no detections), 99.9ms
# Speed: 0.9ms preprocess, 99.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 22924.62, CNN: accident
# Accident Detected. accident
# Alert sent. Message SID: SM0a4048b6c6304a7a97e8be883b59cc2b
#
# 0: 384x640 (no detections), 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 89673.80, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 83867.59, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 88969.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 55.4ms
# Speed: 13.4ms preprocess, 55.4ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 92944.45, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 75.8ms
# Speed: 0.0ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 89161.90, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 75.8ms
# Speed: 0.0ms preprocess, 75.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 85895.96, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 64.6ms
# Speed: 0.0ms preprocess, 64.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 87934.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 77.2ms
# Speed: 0.0ms preprocess, 77.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 88914.07, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 5.5ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 89888.59, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 70.7ms
# Speed: 6.5ms preprocess, 70.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 93078.29, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 69.7ms
# Speed: 12.0ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 86603.30, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 55.7ms
# Speed: 0.0ms preprocess, 55.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 89632.84, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 87736.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 70.5ms
# Speed: 3.6ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 83960.92, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 65.3ms
# Speed: 15.6ms preprocess, 65.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 86791.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 88338.66, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 64.5ms
# Speed: 15.6ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 86223.92, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 74.0ms
# Speed: 0.0ms preprocess, 74.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 85232.80, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 56.8ms
# Speed: 0.0ms preprocess, 56.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 84365.85, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 85.2ms
# Speed: 0.0ms preprocess, 85.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 86872.79, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 76.1ms
# Speed: 0.0ms preprocess, 76.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 89348.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 96986.26, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 518704.56, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 60.1ms
# Speed: 0.0ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 738153.12, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 67.3ms
# Speed: 0.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 912155.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 63.9ms
# Speed: 0.0ms preprocess, 63.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 950599.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 719881.81, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 60.0ms
# Speed: 6.9ms preprocess, 60.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 885426.31, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 toilet, 74.6ms
# Speed: 0.0ms preprocess, 74.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 1045590.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 toilet, 72.1ms
# Speed: 0.0ms preprocess, 72.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 1706354.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 toilet, 69.7ms
# Speed: 3.5ms preprocess, 69.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 2244127.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 toilet, 57.1ms
# Speed: 0.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 2668775.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 2142765.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.3ms
# Speed: 0.0ms preprocess, 57.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 2096989.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 1916940.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 59.9ms
# Speed: 0.0ms preprocess, 59.9ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 2053312.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 56.6ms
# Speed: 0.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 2354470.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 toilet, 73.1ms
# Speed: 0.0ms preprocess, 73.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 2485755.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 toilet, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 14.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 1829978.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 62.3ms
# Speed: 0.0ms preprocess, 62.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 1055157.75, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 56.3ms
# Speed: 8.2ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 674419.81, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 (no detections), 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 798485.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 507256.66, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 65.8ms
# Speed: 0.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 363029.66, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 56.8ms
# Speed: 0.0ms preprocess, 56.8ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 274076.94, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 217867.19, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 189618.09, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 101.6ms
# Speed: 0.0ms preprocess, 101.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 189450.23, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 63.1ms
# Speed: 0.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 192371.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 59.0ms
# Speed: 0.0ms preprocess, 59.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 189551.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 52.0ms
# Speed: 2.3ms preprocess, 52.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 189859.56, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 186237.34, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 60.5ms
# Speed: 0.0ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 193016.77, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 63.3ms
# Speed: 0.0ms preprocess, 63.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 180612.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 177282.09, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 58.0ms
# Speed: 8.1ms preprocess, 58.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 175933.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 167870.52, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 161011.08, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 bus, 61.1ms
# Speed: 1.3ms preprocess, 61.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 152055.23, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 bus, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 187391.05, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 57.1ms
# Speed: 15.6ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 3, Motion: 289040.03, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 58.9ms
# Speed: 2.5ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 375486.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 60.8ms
# Speed: 0.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 453387.41, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 69.8ms
# Speed: 0.0ms preprocess, 69.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 593729.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.2ms
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 749916.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 bus, 81.5ms
# Speed: 0.0ms preprocess, 81.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 831113.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 79.8ms
# Speed: 8.0ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 871948.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 65.1ms
# Speed: 14.0ms preprocess, 65.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 936646.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 61.2ms
# Speed: 0.0ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 967696.06, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 63.6ms
# Speed: 0.0ms preprocess, 63.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 3, Motion: 926941.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 58.2ms
# Speed: 0.0ms preprocess, 58.2ms inference, 16.3ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 1045164.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.4ms
# Speed: 0.0ms preprocess, 61.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 1023431.94, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.3ms
# Speed: 0.5ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 1019989.81, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.6ms
# Speed: 11.0ms preprocess, 59.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 920059.81, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 900898.38, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 786658.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.9ms
# Speed: 0.0ms preprocess, 56.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 781603.12, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.5ms
# Speed: 4.0ms preprocess, 69.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 756225.88, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 747696.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 63.8ms
# Speed: 7.1ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 732154.31, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 707324.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 684533.69, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 71.7ms
# Speed: 6.1ms preprocess, 71.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 633070.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 579190.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 60.3ms
# Speed: 9.6ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 530122.38, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.4ms
# Speed: 0.0ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 490533.06, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 66.3ms
# Speed: 0.0ms preprocess, 66.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 459467.19, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 1 car, 1 truck, 65.4ms
# Speed: 12.5ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 1, Motion: 460414.59, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 1 truck, 56.3ms
# Speed: 12.0ms preprocess, 56.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 0, Motion: 458473.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 3 cars, 62.7ms
# Speed: 3.3ms preprocess, 62.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 436092.03, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 372282.44, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.1ms
# Speed: 13.0ms preprocess, 56.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 265327.28, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 207660.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 77.4ms
# Speed: 0.0ms preprocess, 77.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 153986.78, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 106534.43, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 126084.65, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 77.8ms
# Speed: 0.0ms preprocess, 77.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 143908.86, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 78.8ms
# Speed: 0.0ms preprocess, 78.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 151413.19, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.2ms
# Speed: 7.5ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 144838.75, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.7ms
# Speed: 0.0ms preprocess, 65.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 125554.34, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.7ms
# Speed: 5.5ms preprocess, 67.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 106038.35, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 71.1ms
# Speed: 0.0ms preprocess, 71.1ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 97072.49, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 71.2ms
# Speed: 0.0ms preprocess, 71.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 86030.06, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 83441.76, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.6ms
# Speed: 7.0ms preprocess, 56.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 84908.03, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.2ms
# Speed: 0.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 83074.09, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 79852.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.9ms
# Speed: 0.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 73726.04, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 78.9ms
# Speed: 0.0ms preprocess, 78.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 65073.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.9ms
# Speed: 3.0ms preprocess, 72.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 67951.86, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.6ms
# Speed: 0.0ms preprocess, 70.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 67723.73, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 59640.81, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.4ms
# Speed: 4.9ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51395.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 58365.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.7ms
# Speed: 0.7ms preprocess, 68.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 60433.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 81.1ms
# Speed: 0.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 56552.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 71.5ms
# Speed: 0.0ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 58731.22, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.6ms
# Speed: 10.0ms preprocess, 66.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 58176.34, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 88.4ms
# Speed: 0.0ms preprocess, 88.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 54903.11, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.8ms
# Speed: 0.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 56995.72, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.7ms
# Speed: 0.0ms preprocess, 70.7ms inference, 0.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51182.87, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.1ms
# Speed: 8.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52916.38, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 81.2ms
# Speed: 0.0ms preprocess, 81.2ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 53447.10, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.9ms
# Speed: 3.6ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52029.18, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.5ms
# Speed: 0.0ms preprocess, 74.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 53357.74, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.4ms
# Speed: 7.4ms preprocess, 68.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51079.38, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51725.74, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 228.4ms
# Speed: 4.5ms preprocess, 228.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49999.32, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 92.0ms
# Speed: 0.0ms preprocess, 92.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50854.83, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 91.6ms
# Speed: 9.5ms preprocess, 91.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 53312.83, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50972.98, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 86.0ms
# Speed: 3.7ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50583.05, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.2ms
# Speed: 0.0ms preprocess, 69.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48881.33, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.9ms
# Speed: 8.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51880.14, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.8ms
# Speed: 0.0ms preprocess, 61.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49520.41, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50523.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.4ms
# Speed: 0.0ms preprocess, 68.4ms inference, 6.4ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49774.97, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49863.36, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48720.14, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.9ms
# Speed: 0.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50827.12, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51382.06, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 63.9ms
# Speed: 0.0ms preprocess, 63.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51053.05, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 71.6ms
# Speed: 0.0ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47916.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49296.91, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.5ms
# Speed: 0.0ms preprocess, 72.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48186.28, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50415.92, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.4ms
# Speed: 2.7ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50386.45, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.2ms
# Speed: 5.8ms preprocess, 72.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48634.30, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 73.9ms
# Speed: 1.1ms preprocess, 73.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48532.43, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.8ms
# Speed: 0.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47937.86, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 60.5ms
# Speed: 3.5ms preprocess, 60.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49071.91, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.1ms
# Speed: 0.0ms preprocess, 61.1ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50814.55, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.9ms
# Speed: 8.1ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49022.92, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 92.2ms
# Speed: 0.0ms preprocess, 92.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 54240.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.8ms
# Speed: 0.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49526.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.2ms
# Speed: 2.9ms preprocess, 62.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47497.46, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.1ms
# Speed: 0.0ms preprocess, 66.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51203.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.5ms
# Speed: 0.0ms preprocess, 68.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48134.30, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 53663.98, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.4ms
# Speed: 0.0ms preprocess, 67.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48997.61, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.2ms
# Speed: 0.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49180.11, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 58.1ms
# Speed: 0.0ms preprocess, 58.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49109.70, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 58.9ms
# Speed: 0.0ms preprocess, 58.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49654.32, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 63.5ms
# Speed: 12.5ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50225.63, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.6ms
# Speed: 0.0ms preprocess, 61.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48352.95, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.0ms
# Speed: 0.0ms preprocess, 70.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50603.66, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.6ms
# Speed: 0.0ms preprocess, 72.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49212.35, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 60.3ms
# Speed: 13.5ms preprocess, 60.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48628.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.7ms
# Speed: 3.0ms preprocess, 55.7ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48591.92, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 63.5ms
# Speed: 0.0ms preprocess, 63.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49706.84, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.5ms
# Speed: 8.0ms preprocess, 55.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49292.32, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50658.56, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 0.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50383.91, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.5ms
# Speed: 0.0ms preprocess, 56.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48432.95, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 60.2ms
# Speed: 11.0ms preprocess, 60.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49120.13, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 58.4ms
# Speed: 11.1ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52043.95, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.6ms
# Speed: 5.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48846.05, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 56.7ms
# Speed: 0.0ms preprocess, 56.7ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 53538.15, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 87.0ms
# Speed: 0.0ms preprocess, 87.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49471.25, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.2ms
# Speed: 7.7ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50482.07, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.2ms
# Speed: 10.5ms preprocess, 59.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48844.65, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.4ms
# Speed: 0.0ms preprocess, 65.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51147.94, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.0ms
# Speed: 6.5ms preprocess, 62.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 56301.41, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.9ms
# Speed: 8.0ms preprocess, 64.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52130.54, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.3ms
# Speed: 0.0ms preprocess, 59.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52018.29, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.1ms
# Speed: 0.0ms preprocess, 59.1ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50138.84, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.4ms
# Speed: 4.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51251.05, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.1ms
# Speed: 0.0ms preprocess, 57.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49295.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 75.5ms
# Speed: 0.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48206.51, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.6ms
# Speed: 0.0ms preprocess, 55.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 51382.61, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 71.4ms
# Speed: 0.0ms preprocess, 71.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47817.41, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.0ms
# Speed: 0.0ms preprocess, 57.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50524.39, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48296.74, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 67.9ms
# Speed: 0.0ms preprocess, 67.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49744.16, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.6ms
# Speed: 0.0ms preprocess, 66.6ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50715.11, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.3ms
# Speed: 2.8ms preprocess, 55.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49042.87, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.8ms
# Speed: 0.0ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 52402.15, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 57.5ms
# Speed: 8.2ms preprocess, 57.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48847.82, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.5ms
# Speed: 10.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49016.72, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.5ms
# Speed: 0.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50233.74, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.3ms
# Speed: 0.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48018.04, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.2ms
# Speed: 0.0ms preprocess, 65.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50062.66, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 55.4ms
# Speed: 0.0ms preprocess, 55.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48698.50, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 74.1ms
# Speed: 0.0ms preprocess, 74.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48118.68, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 77.7ms
# Speed: 0.0ms preprocess, 77.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49254.84, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47693.54, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 63.8ms
# Speed: 0.0ms preprocess, 63.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47775.54, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48414.16, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.1ms
# Speed: 0.0ms preprocess, 59.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48262.03, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.9ms
# Speed: 4.2ms preprocess, 66.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48069.15, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 72.4ms
# Speed: 6.9ms preprocess, 72.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47097.53, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.5ms
# Speed: 8.0ms preprocess, 62.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47511.62, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.7ms
# Speed: 0.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48310.57, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 59.7ms
# Speed: 0.0ms preprocess, 59.7ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 50645.09, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 65.9ms
# Speed: 0.0ms preprocess, 65.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49457.39, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48186.59, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 68.1ms
# Speed: 0.0ms preprocess, 68.1ms inference, 11.3ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48920.70, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.2ms
# Speed: 0.0ms preprocess, 64.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 48131.52, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 64.3ms
# Speed: 0.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 49464.39, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 61.7ms
# Speed: 7.0ms preprocess, 61.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47850.00, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.1ms
# Speed: 0.0ms preprocess, 69.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 46253.48, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 70.9ms
# Speed: 0.0ms preprocess, 70.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 46354.96, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 73.7ms
# Speed: 0.0ms preprocess, 73.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 46000.37, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 66.9ms
# Speed: 0.0ms preprocess, 66.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 47099.22, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 69.6ms
# Speed: 0.0ms preprocess, 69.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 45986.97, CNN: accident
# Accident Detected. accident
#
# 0: 384x640 2 cars, 58.5ms
# Speed: 15.0ms preprocess, 58.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Vehicles: 2, Motion: 46276.56, CNN: accident
# Accident Detected. accident
#
# Model Evaluation Results:
# Accuracy : 1.0000
# Precision: 1.0000
# F1-score : 1.0000
